# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
movies = pd.read_csv('/home/suhasini/Our Data/Our Projects/Python_HandsOn/P4-Section6-Homework-Dataset.csv',encoding='latin1')
movies
# Out:
#     Day of Week                                Director   Genre  \
# 0        Friday                               Brad Bird  action
# 1        Friday                             Scott Waugh  action
# 2        Friday                          Patrick Hughes  action
# 3        Friday                 Phil Lord, Chris Miller  comedy
# 4        Friday                         Roland Emmerich  action
# ..          ...                                     ...     ...
# 603   Wednesday                        William Friedkin  horror
# 604   Wednesday                            George Lucas  action
# 605      Friday                           James Cameron  sci-fi
# 606   Wednesday                           James Cameron   drama
# 607      Friday  George Cukor, Victor Fleming, Sam Wood   drama
#
#             Movie Title Release Date               Studio  \
# 0          Tomorrowland   22/05/2015  Buena Vista Studios
# 1        Need for Speed   14/03/2014  Buena Vista Studios
# ...

# %%
movies.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
movies.columns = ['DayofWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGrossInMill', 'BudgetInMill', 'GrossInMill',
       'IMDbRating', 'MovieLensRating', 'OverseasInMill', 'Overseas%',
       'ProfitInMill', 'Profit%', 'RuntimeInMin', 'USInMill',
       'Gross%US']

# %%
movies.columns
# Out:
# Index(['DayofWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate', 'Studio',
#        'AdjustedGrossInMill', 'BudgetInMill', 'GrossInMill', 'IMDbRating',
#        'MovieLensRating', 'OverseasInMill', 'Overseas%', 'ProfitInMill',
#        'Profit%', 'RuntimeInMin', 'USInMill', 'Gross%US'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day of Week               608 non-null object
# Director                  608 non-null object
# Genre                     608 non-null object
# Movie Title               608 non-null object
# Release Date              608 non-null object
# Studio                    608 non-null object
# Adjusted Gross ($mill)    608 non-null object
# Budget ($mill)            608 non-null float64
# Gross ($mill)             608 non-null object
# IMDb Rating               608 non-null float64
# MovieLens Rating          608 non-null float64
# Overseas ($mill)          608 non-null object
# Overseas%                 608 non-null float64
# Profit ($mill)            608 non-null object
# Profit%                   608 non-null float64
# Runtime (min)             608 non-null int64
# US ($mill)                608 non-null float64
# Gross % US                608 non-null float64
# ...

# %%
# movies.Genre = movies.Genre.astype('category')
# movies.DayofWeek = movies.DayofWeek.astype('category')

# %%
sns.set(style='darkgrid', palette='twilight_shifted', color_codes=True, rc={'figure.figsize':(15,10)})

filtered_Genre = ['action', 'comedy', 'adventure', 'animation', 'drama']
movies_filt1 = movies[movies.Genre.isin(filtered_Genre)]

filtered_Studio = ['Buena Vista Studios', 'Sony', 'Universal', 'WB', 'Paramount Pictures', 'Fox']
movies_filt2 = movies_filt1[movies_filt1.Studio.isin(filtered_Studio)]

movies_filtered = movies_filt2
len(movies_filtered)
# Out:
# 423

# %%
g = sns.boxplot(data=movies_filtered, x='Genre', y='Gross%US', orient='v', color='lightgray', showfliers=False)
plt.setp(g.artists, alpha=0.5)

sns.stripplot(data=movies_filtered, x='Genre', y='Gross%US', jitter=True, size=6, hue='Studio',linewidth=0, \
              alpha=0.7)

g.axes.set_title('Domestic Gross % by Genre', fontsize =30)
g.set_xlabel('Genre', fontsize=20)
g.set_ylabel('Gross % US', fontsize=20)
g.set(ylim= (0,100))
g.legend(bbox_to_anchor=(1.05,1), loc=2)
